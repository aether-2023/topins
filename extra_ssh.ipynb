# %%
import sympy as sp

# Define symbolic variables
t, kx, ky = sp.symbols('t kx ky', real=True)
s11, s12, s13, s14 = sp.symbols('s11 s12 s13 s14')
s21, s22, s23, s24 = sp.symbols('s21 s22 s23 s24')
s31, s32, s33, s34 = sp.symbols('s31 s32 s33 s34')
s41, s42, s43, s44 = sp.symbols('s41 s42 s43 s44')

# Define matrix S
S = sp.Matrix([
    [s11, s12, s13, s14],
    [s21, s22, s23, s24],
    [s31, s32, s33, s34],
    [s41, s42, s43, s44]
])

# Define matrices A and B
A = sp.Matrix([
    [0, 1 + t * sp.exp(sp.I * kx), 0, 1],
    [1, 0, -1 - t * sp.exp(-sp.I * ky), 0],
    [0, -1, 0, 1 + t * sp.exp(-sp.I * kx)],
    [1 + t * sp.exp(sp.I * ky), 0, 1, 0]
])

B = sp.Matrix([
    [0, 1 + t * sp.exp(-sp.I * ky), 0, 1],
    [1, 0, -1 - t * sp.exp(-sp.I * kx), 0],
    [0, -1, 0, 1 + t * sp.exp(sp.I * ky)],
    [1 + t * sp.exp(sp.I * kx), 0, 1, 0]
])

# Define the equation S*A = B*S
equation = sp.Eq(S * A, B * S)

# Expand the equation to get a system of equations
equations = []
for i in range(4):
    for j in range(4):
        eq = sp.simplify((S * A - B * S)[i, j])
        equations.append(sp.Eq(eq, 0))

# Attempt to solve the system
solution = sp.solve(
    equations,
    (s11, s12, s13, s14,
     s21, s22, s23, s24,
     s31, s32, s33, s34,
     s41, s42, s43, s44),
    dict=True
)

# Check if any solution was found
if solution:
    S_solution = solution[0]
    print("Solution found:")
    sp.pprint(S_solution)

    # Now, construct the solution matrix only with available variables
    # Assign free symbols if they are not solved
    S_matrix_entries = []
    symbols = [s11, s12, s13, s14,
               s21, s22, s23, s24,
               s31, s32, s33, s34,
               s41, s42, s43, s44]
    
    for i in range(4):
        row = []
        for j in range(4):
            symbol = symbols[i*4 + j]
            value = S_solution.get(symbol, symbol)  # Use the symbol itself if not solved
            row.append(value)
        S_matrix_entries.append(row)

    S_matrix = sp.Matrix(S_matrix_entries)
    print("\nSolution Matrix S:")
    sp.pprint(S_matrix)
else:
    print("\nNo solution found or the system is too complex to solve analytically.")
# Out:
# Solution found:
# ⎧                            ⎛ 2  ⅈ⋅kx    2  ⅈ⋅ky      2⋅ⅈ⋅kx      2⋅ⅈ⋅ky    2 ↪
# ⎪                        s₄₂⋅⎝t ⋅ℯ     - t ⋅ℯ     + t⋅ℯ       - t⋅ℯ       + ℯ  ↪
# ⎨s₁₁: ──────────────────────────────────────────────────────────────────────── ↪
# ⎪      3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky      2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅k ↪
# ⎩     t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ      ⋅ℯ     + 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ    ↪
#
# ↪ ⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞                          ⎛ 3  ⅈ ↪
# ↪      ⋅ℯ     - ℯ    ⋅ℯ       + ℯ     - ℯ    ⎠                      s₄₄⋅⎝t ⋅ℯ  ↪
# ↪ ─────────────────────────────────────────────────────────────── + ────────── ↪
# ↪ y        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky          2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx              ↪
# ↪   + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ     + 2⋅ℯ                  ↪
#
# ↪ ⋅kx  ⅈ⋅ky    2  2⋅ⅈ⋅kx  ⅈ⋅ky    2  ⅈ⋅kx  2⋅ⅈ⋅ky    2  ⅈ⋅kx    2  ⅈ⋅ky      2 ↪
# ↪    ⋅ℯ     + t ⋅ℯ      ⋅ℯ     + t ⋅ℯ    ⋅ℯ       + t ⋅ℯ     + t ⋅ℯ     + t⋅ℯ  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                     3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky      2  ⅈ⋅kx   ↪
# ↪                    t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ      ⋅ℯ     + 2⋅t ⋅ℯ     + ↪
#
# ↪ ⋅ⅈ⋅kx  2⋅ⅈ⋅ky      2⋅ⅈ⋅kx        ⅈ⋅kx  ⅈ⋅ky      2⋅ⅈ⋅ky        2⋅ⅈ⋅kx  ⅈ⋅ky  ↪
# ↪      ⋅ℯ       + t⋅ℯ       + 2⋅t⋅ℯ    ⋅ℯ     + t⋅ℯ       + t + ℯ      ⋅ℯ      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪     3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky          2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅ ↪
# ↪  t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ     + 2⋅ℯ   ↪
#
# ↪    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞                     ⎛ 2⋅ⅈ⋅ky    ⎞           ↪
# ↪ + ℯ    ⋅ℯ       + ℯ     + ℯ    ⎠                 s₄₃⋅⎝ℯ       - 1⎠           ↪
# ↪ ────────────────────────────────, s₁₂: s₄₁ + ─────────────────────────, s₁₃: ↪
# ↪ kx                                              ⅈ⋅kx    ⅈ⋅kx  ⅈ⋅ky           ↪
# ↪                                              t⋅ℯ     + ℯ    ⋅ℯ     + 1       ↪
#
# ↪                 ⎛   3  ⅈ⋅kx    2  2⋅ⅈ⋅kx      2  ⅈ⋅kx  ⅈ⋅ky    2        2⋅ⅈ⋅ ↪
# ↪             s₄₂⋅⎝- t ⋅ℯ     - t ⋅ℯ       - 2⋅t ⋅ℯ    ⋅ℯ     - t  - 2⋅t⋅ℯ     ↪
# ↪  ─────────────────────────────────────────────────────────────────────────── ↪
# ↪   3  2⋅ⅈ⋅kx  ⅈ⋅ky    2  3⋅ⅈ⋅kx  ⅈ⋅ky    2  2⋅ⅈ⋅kx  2⋅ⅈ⋅ky      2  ⅈ⋅kx  ⅈ⋅ky ↪
# ↪  t ⋅ℯ      ⋅ℯ     + t ⋅ℯ      ⋅ℯ     + t ⋅ℯ      ⋅ℯ       + 2⋅t ⋅ℯ    ⋅ℯ     ↪
#
# ↪ kx  ⅈ⋅ky        ⅈ⋅kx        ⅈ⋅ky    2⋅ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx  3⋅ⅈ⋅ky      ⅈ⋅kx ↪
# ↪   ⋅ℯ     - 2⋅t⋅ℯ     - 2⋅t⋅ℯ     - ℯ      ⋅ℯ       + ℯ    ⋅ℯ       - 3⋅ℯ     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪       3⋅ⅈ⋅kx  2⋅ⅈ⋅ky        2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx  2⋅ⅈ⋅ky      ⅈ⋅ky      2⋅ ↪
# ↪  + t⋅ℯ      ⋅ℯ       + 3⋅t⋅ℯ      ⋅ℯ     + t⋅ℯ    ⋅ℯ       + t⋅ℯ     + 2⋅ℯ   ↪
#
# ↪   ⅈ⋅ky    2⋅ⅈ⋅ky⎞                                ⎛   2  2⋅ⅈ⋅kx  ⅈ⋅ky    2  ⅈ ↪
# ↪ ⋅ℯ     - ℯ      ⎠                            s₄₄⋅⎝- t ⋅ℯ      ⋅ℯ     + t ⋅ℯ  ↪
# ↪ ──────────────────────────── + ───────────────────────────────────────────── ↪
# ↪ ⅈ⋅kx  2⋅ⅈ⋅ky      ⅈ⋅kx  ⅈ⋅ky    3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky    ↪
# ↪     ⋅ℯ       + 2⋅ℯ    ⋅ℯ       t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ      ⋅ℯ     +  ↪
#
# ↪ ⋅kx      2⋅ⅈ⋅kx  2⋅ⅈ⋅ky        2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞ ↪
# ↪     - t⋅ℯ      ⋅ℯ       + t - ℯ      ⋅ℯ     - ℯ    ⋅ℯ       + ℯ     + ℯ    ⎠ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪    2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky          2⋅ⅈ⋅kx   ↪
# ↪ 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ ↪
#
# ↪                               ⎛     ⅈ⋅kx    ⅈ⋅ky⎞                ⎛   2⋅ⅈ⋅ky  ↪
# ↪                           s₄₃⋅⎝t + ℯ     + ℯ    ⎠            s₄₃⋅⎝t⋅ℯ        ↪
# ↪ ──────────────, s₁₄: ─────────────────────────────────, s₂₁: ─────────────── ↪
# ↪ ⅈ⋅ky      ⅈ⋅kx          2⋅ⅈ⋅kx    2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx             2⋅ⅈ⋅kx    ↪
# ↪      + 2⋅ℯ           t⋅ℯ       + ℯ      ⋅ℯ     + ℯ              t⋅ℯ       +  ↪
#
# ↪    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅ky⎞               ⎛     2⋅ⅈ⋅ky⎞           ⎛   ⅈ⋅kx  2⋅ⅈ ↪
# ↪ + ℯ    ⋅ℯ       + ℯ    ⎠           s₄₂⋅⎝1 - ℯ      ⎠       s₄₄⋅⎝t⋅ℯ    ⋅ℯ    ↪
# ↪ ────────────────────────, s₂₂: ───────────────────────── + ───────────────── ↪
# ↪  2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx             ⅈ⋅kx    ⅈ⋅kx  ⅈ⋅ky                    ⅈ⋅kx ↪
# ↪ ℯ      ⋅ℯ     + ℯ              t⋅ℯ     + ℯ    ⋅ℯ     + 1             t⋅ℯ     ↪
#
# ↪ ⋅ky    ⅈ⋅kx  ⅈ⋅ky    2⋅ⅈ⋅ky⎞                  ⎛   2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ ↪
# ↪     + ℯ    ⋅ℯ     + ℯ      ⎠              s₄₃⋅⎝- ℯ      ⋅ℯ     - ℯ    ⋅ℯ     ↪
# ↪ ────────────────────────────, s₂₃: -s₄₁ + ────────────────────────────────── ↪
# ↪     ⅈ⋅kx  ⅈ⋅ky                                         2⋅ⅈ⋅kx    2⋅ⅈ⋅kx  ⅈ⋅k ↪
# ↪  + ℯ    ⋅ℯ     + 1                                  t⋅ℯ       + ℯ      ⋅ℯ    ↪
#
# ↪ ky    ⅈ⋅kx    ⅈ⋅ky⎞               ⎛      ⅈ⋅kx    ⅈ⋅ky⎞              ⎛   2⋅ⅈ⋅ ↪
# ↪    + ℯ     + ℯ    ⎠           s₄₂⋅⎝-t - ℯ     - ℯ    ⎠          s₄₄⋅⎝- ℯ     ↪
# ↪ ───────────────────, s₂₄: ───────────────────────────────── + ────────────── ↪
# ↪ y    ⅈ⋅kx                    2⋅ⅈ⋅kx    2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx      2⋅ⅈ⋅kx    2 ↪
# ↪   + ℯ                     t⋅ℯ       + ℯ      ⋅ℯ     + ℯ       t⋅ℯ       + ℯ  ↪
#
# ↪ kx  ⅈ⋅ky    ⅈ⋅ky⎞             ⎛ 3  ⅈ⋅kx  ⅈ⋅ky    2  2⋅ⅈ⋅kx  ⅈ⋅ky    2  ⅈ⋅kx  ↪
# ↪   ⋅ℯ     + ℯ    ⎠         s₄₂⋅⎝t ⋅ℯ    ⋅ℯ     + t ⋅ℯ      ⋅ℯ     + t ⋅ℯ    ⋅ ↪
# ↪ ───────────────────, s₃₁: ────────────────────────────────────────────────── ↪
# ↪ ⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx                                     3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅ ↪
# ↪      ⋅ℯ     + ℯ                                        t ⋅ℯ       + t ⋅ℯ     ↪
#
# ↪  2⋅ⅈ⋅ky    2  ⅈ⋅kx    2  ⅈ⋅ky      2⋅ⅈ⋅kx  2⋅ⅈ⋅ky      2⋅ⅈ⋅kx        ⅈ⋅kx  ⅈ ↪
# ↪ ℯ       + t ⋅ℯ     + t ⋅ℯ     + t⋅ℯ      ⋅ℯ       + t⋅ℯ       + 2⋅t⋅ℯ    ⋅ℯ  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky      2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx ↪
# ↪    + t ⋅ℯ      ⋅ℯ     + 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ     ↪
#
# ↪ ⋅ky      2⋅ⅈ⋅ky        2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞         ↪
# ↪     + t⋅ℯ       + t + ℯ      ⋅ℯ     + ℯ    ⋅ℯ       + ℯ     + ℯ    ⎠         ↪
# ↪ ──────────────────────────────────────────────────────────────────── + ───── ↪
# ↪   ⅈ⋅ky          2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx                                  3  2 ↪
# ↪ ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ     + 2⋅ℯ                                     t ⋅ℯ  ↪
#
# ↪           ⎛ 2  2⋅ⅈ⋅kx  ⅈ⋅ky    2  ⅈ⋅kx  2⋅ⅈ⋅ky      2⋅ⅈ⋅kx      2⋅ⅈ⋅ky    2⋅ ↪
# ↪       s₄₄⋅⎝t ⋅ℯ      ⋅ℯ     - t ⋅ℯ    ⋅ℯ       + t⋅ℯ       - t⋅ℯ       + ℯ   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky      2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky         ↪
# ↪       + t ⋅ℯ       + t ⋅ℯ      ⋅ℯ     + 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ ↪
#
# ↪ ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞                      ⎛     ⅈ⋅kx  ↪
# ↪     ⋅ℯ     - ℯ    ⋅ℯ       + ℯ     - ℯ    ⎠                  s₄₃⋅⎝- t⋅ℯ    ⋅ ↪
# ↪ ──────────────────────────────────────────────────────, s₃₂: ─────────────── ↪
# ↪ 2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky          2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx                     ⅈ ↪
# ↪        + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ     + 2⋅ℯ                      t⋅ℯ  ↪
#
# ↪  2⋅ⅈ⋅ky    ⅈ⋅kx  ⅈ⋅ky    2⋅ⅈ⋅ky⎞                         ⎛   2  2⋅ⅈ⋅kx  ⅈ⋅ky ↪
# ↪ ℯ       - ℯ    ⋅ℯ     - ℯ      ⎠                     s₄₂⋅⎝- t ⋅ℯ      ⋅ℯ     ↪
# ↪ ────────────────────────────────, s₃₃: ───────────────────────────────────── ↪
# ↪ ⋅kx    ⅈ⋅kx  ⅈ⋅ky                       3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ↪
# ↪     + ℯ    ⋅ℯ     + 1                  t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ      ⋅ ↪
#
# ↪     2  ⅈ⋅kx      2⋅ⅈ⋅kx  2⋅ⅈ⋅ky        2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx  ↪
# ↪  + t ⋅ℯ     - t⋅ℯ      ⋅ℯ       + t - ℯ      ⋅ℯ     - ℯ    ⋅ℯ       + ℯ      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪  ⅈ⋅ky      2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky           ↪
# ↪ ℯ     + 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ ↪
#
# ↪    ⅈ⋅ky⎞                     ⎛ 3  3⋅ⅈ⋅kx  ⅈ⋅ky    2  3⋅ⅈ⋅kx  2⋅ⅈ⋅ky    2  3⋅ ↪
# ↪ + ℯ    ⎠                 s₄₄⋅⎝t ⋅ℯ      ⋅ℯ     + t ⋅ℯ      ⋅ℯ       + t ⋅ℯ   ↪
# ↪ ────────────────────── + ─────────────────────────────────────────────────── ↪
# ↪ 2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx                            3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx     ↪
# ↪       ⋅ℯ     + 2⋅ℯ                               t ⋅ℯ       + t ⋅ℯ       + t ↪
#
# ↪ ⅈ⋅kx      2  2⋅ⅈ⋅kx  ⅈ⋅ky        3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx  2⋅ⅈ⋅ky        2 ↪
# ↪      + 2⋅t ⋅ℯ      ⋅ℯ     + 2⋅t⋅ℯ      ⋅ℯ     + 2⋅t⋅ℯ      ⋅ℯ       + 2⋅t⋅ℯ  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ 2  2⋅ⅈ⋅kx  ⅈ⋅ky      2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky ↪
# ↪  ⋅ℯ      ⋅ℯ     + 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     ↪
#
# ↪ ⋅ⅈ⋅kx      2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞                     ↪
# ↪       + 3⋅ℯ      ⋅ℯ     + ℯ    ⋅ℯ       + ℯ     - ℯ    ⎠                s₄₃⋅ ↪
# ↪ ────────────────────────────────────────────────────────, s₃₄: s₄₁ + ─────── ↪
# ↪           2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx                                        2⋅ⅈ⋅ ↪
# ↪  + t + 2⋅ℯ      ⋅ℯ     + 2⋅ℯ                                         t⋅ℯ     ↪
#
# ↪ ⎛ 2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅ky⎞   ⎫
# ↪ ⎝ℯ      ⋅ℯ     - ℯ    ⎠   ⎪
# ↪ ──────────────────────────⎬
# ↪ kx    2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx⎪
# ↪    + ℯ      ⋅ℯ     + ℯ    ⎭
#
# Solution Matrix S:
# ⎡                       ⎛ 2  ⅈ⋅kx    2  ⅈ⋅ky      2⋅ⅈ⋅kx      2⋅ⅈ⋅ky    2⋅ⅈ⋅kx ↪
# ⎢                   s₄₂⋅⎝t ⋅ℯ     - t ⋅ℯ     + t⋅ℯ       - t⋅ℯ       + ℯ       ↪
# ⎢───────────────────────────────────────────────────────────────────────────── ↪
# ⎢ 3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky      2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky     ↪
# ⎢t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ      ⋅ℯ     + 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3 ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢    ⎛ 3  ⅈ⋅kx  ⅈ⋅ky    2  2⋅ⅈ⋅kx  ⅈ⋅ky    2  ⅈ⋅kx  2⋅ⅈ⋅ky    2  ⅈ⋅kx    2  ⅈ⋅ ↪
# ⎢s₄₂⋅⎝t ⋅ℯ    ⋅ℯ     + t ⋅ℯ      ⋅ℯ     + t ⋅ℯ    ⋅ℯ       + t ⋅ℯ     + t ⋅ℯ   ↪
# ⎢───────────────────────────────────────────────────────────────────────────── ↪
# ⎢                              3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky       ↪
# ⎢                             t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ      ⋅ℯ     + 2⋅t ↪
# ⎢                                                                              ↪
# ⎣                                                                              ↪
#
# ↪   ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞                          ⎛ 3  ⅈ⋅kx   ↪
# ↪ ⋅ℯ     - ℯ    ⋅ℯ       + ℯ     - ℯ    ⎠                      s₄₄⋅⎝t ⋅ℯ    ⋅ℯ ↪
# ↪ ────────────────────────────────────────────────────────── + ─────────────── ↪
# ↪     2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky          2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx                   ↪
# ↪ ⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ     + 2⋅ℯ                       ↪
# ↪                                                                              ↪
# ↪                                                                          ⎛   ↪
# ↪                                                                      s₄₃⋅⎝t⋅ ↪
# ↪                                                                      ─────── ↪
# ↪                                                                            2 ↪
# ↪                                                                         t⋅ℯ  ↪
# ↪                                                                              ↪
# ↪ ky      2⋅ⅈ⋅kx  2⋅ⅈ⋅ky      2⋅ⅈ⋅kx        ⅈ⋅kx  ⅈ⋅ky      2⋅ⅈ⋅ky        2⋅ⅈ⋅ ↪
# ↪    + t⋅ℯ      ⋅ℯ       + t⋅ℯ       + 2⋅t⋅ℯ    ⋅ℯ     + t⋅ℯ       + t + ℯ     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ 2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky          2⋅ⅈ⋅kx  ⅈ⋅k ↪
# ↪  ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ    ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ⅈ⋅ky    2  2⋅ⅈ⋅kx  ⅈ⋅ky    2  ⅈ⋅kx  2⋅ⅈ⋅ky    2  ⅈ⋅kx    2  ⅈ⋅ky      2⋅ⅈ⋅kx ↪
# ↪      + t ⋅ℯ      ⋅ℯ     + t ⋅ℯ    ⋅ℯ       + t ⋅ℯ     + t ⋅ℯ     + t⋅ℯ       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky      2  ⅈ⋅kx      3 ↪
# ↪               t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ      ⋅ℯ     + 2⋅t ⋅ℯ     + t⋅ℯ  ↪
# ↪                                                                              ↪
# ↪  2⋅ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅ky⎞                                             ↪
# ↪ ℯ       + ℯ    ⋅ℯ       + ℯ    ⎠                                             ↪
# ↪ ────────────────────────────────                                             ↪
# ↪ ⋅ⅈ⋅kx    2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx                                                ↪
# ↪       + ℯ      ⋅ℯ     + ℯ                                                    ↪
# ↪                                                                              ↪
# ↪ kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞                  ⎛ 2  2⋅ⅈ⋅kx  ⅈ⋅ky ↪
# ↪   ⋅ℯ     + ℯ    ⋅ℯ       + ℯ     + ℯ    ⎠              s₄₄⋅⎝t ⋅ℯ      ⋅ℯ     ↪
# ↪ ───────────────────────────────────────── + ──────────────────────────────── ↪
# ↪ y      ⅈ⋅kx                                  3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ ↪
# ↪   + 2⋅ℯ                                     t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ   ↪
# ↪                                                                              ↪
# ↪            s₄₁                                                               ↪
#
# ↪   2⋅ⅈ⋅ky      2⋅ⅈ⋅kx        ⅈ⋅kx  ⅈ⋅ky      2⋅ⅈ⋅ky        2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅ ↪
# ↪ ⋅ℯ       + t⋅ℯ       + 2⋅t⋅ℯ    ⋅ℯ     + t⋅ℯ       + t + ℯ      ⋅ℯ     + ℯ   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky          2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx    ↪
# ↪      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ     + 2⋅ℯ        ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪     2  ⅈ⋅kx  2⋅ⅈ⋅ky      2⋅ⅈ⋅kx      2⋅ⅈ⋅ky    2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky  ↪
# ↪  - t ⋅ℯ    ⋅ℯ       + t⋅ℯ       - t⋅ℯ       + ℯ      ⋅ℯ     - ℯ    ⋅ℯ        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ⅈ⋅kx  ⅈ⋅ky      2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky      ↪
# ↪     ⋅ℯ     + 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t  ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞                                     ⎛ 2⋅ⅈ⋅ky     ↪
# ↪   ⋅ℯ       + ℯ     + ℯ    ⎠                                 s₄₃⋅⎝ℯ       - 1 ↪
# ↪ ───────────────────────────                       s₄₁ + ──────────────────── ↪
# ↪                                                            ⅈ⋅kx    ⅈ⋅kx  ⅈ⋅k ↪
# ↪                                                         t⋅ℯ     + ℯ    ⋅ℯ    ↪
# ↪                                                                              ↪
# ↪                                      ⎛     2⋅ⅈ⋅ky⎞           ⎛   ⅈ⋅kx  2⋅ⅈ⋅k ↪
# ↪                                  s₄₂⋅⎝1 - ℯ      ⎠       s₄₄⋅⎝t⋅ℯ    ⋅ℯ      ↪
# ↪                              ───────────────────────── + ─────────────────── ↪
# ↪                                 ⅈ⋅kx    ⅈ⋅kx  ⅈ⋅ky                    ⅈ⋅kx   ↪
# ↪                              t⋅ℯ     + ℯ    ⋅ℯ     + 1             t⋅ℯ     + ↪
# ↪                                                                              ↪
# ↪    ⅈ⋅kx    ⅈ⋅ky⎞                              ⎛     ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx  ⅈ⋅ ↪
# ↪ + ℯ     - ℯ    ⎠                          s₄₃⋅⎝- t⋅ℯ    ⋅ℯ       - ℯ    ⋅ℯ   ↪
# ↪ ───────────────────────────               ────────────────────────────────── ↪
# ↪      2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx                             ⅈ⋅kx    ⅈ⋅kx  ⅈ⋅ky   ↪
# ↪ + 2⋅ℯ      ⋅ℯ     + 2⋅ℯ                              t⋅ℯ     + ℯ    ⋅ℯ     + ↪
# ↪                                                                              ↪
# ↪                                                                 s₄₂          ↪
#
# ↪ ⎞                                            ⎛   3  ⅈ⋅kx    2  2⋅ⅈ⋅kx      2 ↪
# ↪ ⎠                                        s₄₂⋅⎝- t ⋅ℯ     - t ⋅ℯ       - 2⋅t  ↪
# ↪ ─────                         ────────────────────────────────────────────── ↪
# ↪ y                              3  2⋅ⅈ⋅kx  ⅈ⋅ky    2  3⋅ⅈ⋅kx  ⅈ⋅ky    2  2⋅ⅈ⋅ ↪
# ↪   + 1                         t ⋅ℯ      ⋅ℯ     + t ⋅ℯ      ⋅ℯ     + t ⋅ℯ     ↪
# ↪                                                                              ↪
# ↪ y    ⅈ⋅kx  ⅈ⋅ky    2⋅ⅈ⋅ky⎞                                                   ↪
# ↪   + ℯ    ⋅ℯ     + ℯ      ⎠                                                   ↪
# ↪ ──────────────────────────                                                   ↪
# ↪   ⅈ⋅kx  ⅈ⋅ky                                                                 ↪
# ↪  ℯ    ⋅ℯ     + 1                                                             ↪
# ↪                                                                              ↪
# ↪ ky    2⋅ⅈ⋅ky⎞                                 ⎛   2  2⋅ⅈ⋅kx  ⅈ⋅ky    2  ⅈ⋅kx ↪
# ↪    - ℯ      ⎠                             s₄₂⋅⎝- t ⋅ℯ      ⋅ℯ     + t ⋅ℯ     ↪
# ↪ ─────────────               ──────────────────────────────────────────────── ↪
# ↪                              3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky       ↪
# ↪  1                          t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ      ⋅ℯ     + 2⋅t ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪   ⅈ⋅kx  ⅈ⋅ky    2        2⋅ⅈ⋅kx  ⅈ⋅ky        ⅈ⋅kx        ⅈ⋅ky    2⋅ⅈ⋅kx  2⋅ⅈ ↪
# ↪ ⋅ℯ    ⋅ℯ     - t  - 2⋅t⋅ℯ      ⋅ℯ     - 2⋅t⋅ℯ     - 2⋅t⋅ℯ     - ℯ      ⋅ℯ    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ kx  2⋅ⅈ⋅ky      2  ⅈ⋅kx  ⅈ⋅ky      3⋅ⅈ⋅kx  2⋅ⅈ⋅ky        2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ ↪
# ↪   ⋅ℯ       + 2⋅t ⋅ℯ    ⋅ℯ     + t⋅ℯ      ⋅ℯ       + 3⋅t⋅ℯ      ⋅ℯ     + t⋅ℯ  ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪       2⋅ⅈ⋅kx  2⋅ⅈ⋅ky        2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞    ↪
# ↪  - t⋅ℯ      ⋅ℯ       + t - ℯ      ⋅ℯ     - ℯ    ⋅ℯ       + ℯ     + ℯ    ⎠    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ 2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky          2⋅ⅈ⋅kx  ⅈ⋅k ↪
# ↪  ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ    ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ⋅ky    ⅈ⋅kx  3⋅ⅈ⋅ky      ⅈ⋅kx  ⅈ⋅ky    2⋅ⅈ⋅ky⎞                               ↪
# ↪     + ℯ    ⋅ℯ       - 3⋅ℯ    ⋅ℯ     - ℯ      ⎠                            s₄ ↪
# ↪ ───────────────────────────────────────────────────────── + ──────────────── ↪
# ↪ ⋅kx  2⋅ⅈ⋅ky      ⅈ⋅ky      2⋅ⅈ⋅kx  2⋅ⅈ⋅ky      ⅈ⋅kx  ⅈ⋅ky    3  2⋅ⅈ⋅kx    2  ↪
# ↪    ⋅ℯ       + t⋅ℯ     + 2⋅ℯ      ⋅ℯ       + 2⋅ℯ    ⋅ℯ       t ⋅ℯ       + t ⋅ ↪
# ↪                                                                              ↪
# ↪                  ⎛   2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞           ↪
# ↪              s₄₃⋅⎝- ℯ      ⋅ℯ     - ℯ    ⋅ℯ       + ℯ     + ℯ    ⎠           ↪
# ↪       -s₄₁ + ─────────────────────────────────────────────────────           ↪
# ↪                           2⋅ⅈ⋅kx    2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx                     ↪
# ↪                        t⋅ℯ       + ℯ      ⋅ℯ     + ℯ                         ↪
# ↪                                                                              ↪
# ↪                   ⎛ 3  3⋅ⅈ⋅kx  ⅈ⋅ky    2  3⋅ⅈ⋅kx  2⋅ⅈ⋅ky    2  3⋅ⅈ⋅kx      2 ↪
# ↪               s₄₄⋅⎝t ⋅ℯ      ⋅ℯ     + t ⋅ℯ      ⋅ℯ       + t ⋅ℯ       + 2⋅t  ↪
# ↪ ─────────── + ────────────────────────────────────────────────────────────── ↪
# ↪ y      ⅈ⋅kx                            3  2⋅ⅈ⋅kx    2  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx   ↪
# ↪   + 2⋅ℯ                               t ⋅ℯ       + t ⋅ℯ       + t ⋅ℯ      ⋅ℯ ↪
# ↪                                                                              ↪
# ↪                                    s₄₃                                       ↪
#
# ↪   ⎛   2  2⋅ⅈ⋅kx  ⅈ⋅ky    2  ⅈ⋅kx      2⋅ⅈ⋅kx  2⋅ⅈ⋅ky        2⋅ⅈ⋅kx  ⅈ⋅ky     ↪
# ↪ ₄⋅⎝- t ⋅ℯ      ⋅ℯ     + t ⋅ℯ     - t⋅ℯ      ⋅ℯ       + t - ℯ      ⋅ℯ     - ℯ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪  3⋅ⅈ⋅kx    2  2⋅ⅈ⋅kx  ⅈ⋅ky      2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ↪
# ↪ ℯ       + t ⋅ℯ      ⋅ℯ     + 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪   2⋅ⅈ⋅kx  ⅈ⋅ky        3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx  2⋅ⅈ⋅ky        2⋅ⅈ⋅kx       ↪
# ↪ ⋅ℯ      ⋅ℯ     + 2⋅t⋅ℯ      ⋅ℯ     + 2⋅t⋅ℯ      ⋅ℯ       + 2⋅t⋅ℯ       + 3⋅ℯ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ⅈ⋅ky      2  ⅈ⋅kx      3⋅ⅈ⋅kx  ⅈ⋅ky        2⋅ⅈ⋅kx      ⅈ⋅kx  ⅈ⋅ky          2 ↪
# ↪      + 2⋅t ⋅ℯ     + t⋅ℯ      ⋅ℯ     + 3⋅t⋅ℯ       + t⋅ℯ    ⋅ℯ     + t + 2⋅ℯ  ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞                                             ⎛  ↪
# ↪     ⋅ℯ       + ℯ     + ℯ    ⎠                                         s₄₃⋅⎝t ↪
# ↪ ───────────────────────────────────────────                      ─────────── ↪
# ↪  ⅈ⋅kx  ⅈ⋅ky          2⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx                         2⋅ⅈ⋅kx   ↪
# ↪ ℯ    ⋅ℯ     + t + 2⋅ℯ      ⋅ℯ     + 2⋅ℯ                          t⋅ℯ       + ↪
# ↪                                                                              ↪
# ↪                                                        ⎛      ⅈ⋅kx    ⅈ⋅ky⎞  ↪
# ↪                                                    s₄₂⋅⎝-t - ℯ     - ℯ    ⎠  ↪
# ↪                                                ───────────────────────────── ↪
# ↪                                                   2⋅ⅈ⋅kx    2⋅ⅈ⋅kx  ⅈ⋅ky     ↪
# ↪                                                t⋅ℯ       + ℯ      ⋅ℯ     + ℯ ↪
# ↪                                                                              ↪
# ↪ 2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx  2⋅ⅈ⋅ky    ⅈ⋅kx    ⅈ⋅ky⎞                              ⎛ ↪
# ↪       ⋅ℯ     + ℯ    ⋅ℯ       + ℯ     - ℯ    ⎠                          s₄₃⋅⎝ ↪
# ↪ ─────────────────────────────────────────────                 s₄₁ + ──────── ↪
# ↪ ⋅ⅈ⋅kx  ⅈ⋅ky      ⅈ⋅kx                                                  2⋅ⅈ⋅k ↪
# ↪      ⋅ℯ     + 2⋅ℯ                                                   t⋅ℯ      ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪     ⅈ⋅kx    ⅈ⋅ky⎞                       ⎤
# ↪  + ℯ     + ℯ    ⎠                       ⎥
# ↪ ──────────────────────                  ⎥
# ↪   2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx                  ⎥
# ↪  ℯ      ⋅ℯ     + ℯ                      ⎥
# ↪                                         ⎥
# ↪              ⎛   2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅ky⎞  ⎥
# ↪          s₄₄⋅⎝- ℯ      ⋅ℯ     + ℯ    ⎠  ⎥
# ↪ ──── + ─────────────────────────────────⎥
# ↪ ⅈ⋅kx      2⋅ⅈ⋅kx    2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx⎥
# ↪        t⋅ℯ       + ℯ      ⋅ℯ     + ℯ    ⎥
# ↪                                         ⎥
# ↪  2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅ky⎞                  ⎥
# ↪ ℯ      ⋅ℯ     - ℯ    ⎠                  ⎥
# ↪ ─────────────────────────               ⎥
# ↪ x    2⋅ⅈ⋅kx  ⅈ⋅ky    ⅈ⋅kx               ⎥
# ↪   + ℯ      ⋅ℯ     + ℯ                   ⎥
# ↪                                         ⎥
# ↪     s₄₄                                 ⎦

# %%
import sympy as sp

# Define symbolic variables for the matrix T elements
t11, t12, t13, t14 = sp.symbols('t11 t12 t13 t14')
t21, t22, t23, t24 = sp.symbols('t21 t22 t23 t24')
t31, t32, t33, t34 = sp.symbols('t31 t32 t33 t34')
t41, t42, t43, t44 = sp.symbols('t41 t42 t43 t44')

# Define matrix A
a, b, c, d = sp.symbols('a b c d')
A = sp.Matrix([
    [0, a, 0, 1],
    [1, 0, b, 0],
    [0, -1, 0, c],
    [d, 0, 1, 0]
])

# Define matrix B (the desired result)
B = sp.Matrix([
    [0, d, 0, 1],
    [1, 0, -a, 0],
    [0, -1, 0, -b],
    [c, 0, 1, 0]
])

# Define matrix T
T = sp.Matrix([
    [t11, t12, t13, t14],
    [t21, t22, t23, t24],
    [t31, t32, t33, t34],
    [t41, t42, t43, t44]
])

# Compute T inverse
T_inv = T.inv()

# Compute B = T * A * T_inv
B_computed = T * A * T_inv

# Set up the equation B = T * A * T_inv
equation = sp.Eq(B_computed, B)

# Solve for the elements of T
solution = sp.solve(equation, [t11, t12, t13, t14, t21, t22, t23, t24, t31, t32, t33, t34, t41, t42, t43, t44])

# Display the solution
print("Solution for T:")
print(solution)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 44
#      41 equation = sp.Eq(B_computed, B)
#      43 # Solve for the elements of T
# ---> 44 solution = sp.solve(equation, [t11, t12, t13, t14, t21, t22, t23, t24, t31, t32, t33, t34, t41, t42, t43, t44])
#      46 # Display the solution
#      47 print("Solution for T:")
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/solvers.py:1172, in solve(f, *symbols, **flags)
#    1170         solution = _solve(f[0], *symbols, **flags)
#    1171 else:
# -> 1172     linear, solution = _solve_system(f, symbols, **flags)
#    1173 assert type(solution) is list
#    1174 assert not solution or type(solution[0]) is dict, solution
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/solvers.py:1899, in _solve_system(exprs, symbols, **flags)
#    1897 else:
#    1898     try:
# -> 1899         result = solve_poly_system(polys, *symbols)
#    1900         if result:
#    1901             solved_syms = symbols
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/polysys.py:78, in solve_poly_system(seq, strict, *gens, **args)
#      75         except SolveFailed:
#      76             pass
# ---> 78 return solve_generic(polys, opt, strict=strict)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/polysys.py:333, in solve_generic(polys, opt, strict)
#     330     return solutions
#     332 try:
# --> 333     result = _solve_reduced_system(polys, opt.gens, entry=True)
#     334 except CoercionFailed:
#     335     raise NotImplementedError
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/polysys.py:273, in solve_generic.<locals>._solve_reduced_system(system, gens, entry)
#     270     zeros = list(roots(system[0], gens[-1], strict=strict).keys())
#     271     return [(zero,) for zero in zeros]
# --> 273 basis = groebner(system, gens, polys=True)
#     275 if len(basis) == 1 and basis[0].is_ground:
#     276     if not entry:
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/polytools.py:7338, in groebner(F, *gens, **args)
#    7287 @public
#    7288 def groebner(F, *gens, **args):
#    7289     """
#    7290     Computes the reduced Groebner basis for a set of polynomials.
#    7291
#    (...)
#    7336
#    7337     """
# -> 7338     return GroebnerBasis(F, *gens, **args)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/polytools.py:7377, in GroebnerBasis.__new__(cls, F, *gens, **args)
#    7373 ring = PolyRing(opt.gens, opt.domain, opt.order)
#    7375 polys = [ring.from_dict(poly.rep.to_dict()) for poly in polys if poly]
# -> 7377 G = _groebner(polys, ring, method=opt.method)
#    7378 G = [Poly._from_dict(g, opt) for g in G]
#    7380 return cls._new(G, opt)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/groebnertools.py:43, in groebner(seq, ring, method)
#      40     else:
#      41         seq = [ s.set_ring(ring) for s in seq ]
# ---> 43 G = _groebner(seq, ring)
#      45 if orig is not None:
#      46     G = [ g.clear_denoms()[1].set_ring(orig) for g in G ]
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/groebnertools.py:238, in _buchberger(f, ring)
#     236 # ordering divisors is on average more efficient [Cox] page 111
#     237 G1 = sorted(G, key=lambda g: order(f[g].LM))
# --> 238 ht = normal(h, G1)
#     240 if ht:
#     241     G, CP = update(G, CP, ht[1])
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/groebnertools.py:104, in _buchberger.<locals>.normal(g, J)
#     103 def normal(g, J):
# --> 104     h = g.rem([ f[j] for j in J ])
#     106     if not h:
#     107         return None
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:1512, in PolyElement.rem(self, G)
#    1510 for mg, cg in g.iterterms():
#    1511     m1 = monomial_mul(mg, m)
# -> 1512     c1 = get(m1, zero) - c*cg
#    1513     if not c1:
#    1514         del f[m1]
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/fields.py:497, in FracElement.__mul__(f, g)
#     495     return field.zero
#     496 elif isinstance(g, field.dtype):
# --> 497     return f.new(f.numer*g.numer, f.denom*g.denom)
#     498 elif isinstance(g, field.ring.dtype):
#     499     return f.new(f.numer*g, f.denom)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/fields.py:301, in FracElement.new(f, numer, denom)
#     300 def new(f, numer, denom):
# --> 301     return f.raw_new(*numer.cancel(denom))
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:2242, in PolyElement.cancel(self, g)
#    2239 domain = ring.domain
#    2241 if not (domain.is_Field and domain.has_assoc_Ring):
# -> 2242     _, p, q = f.cofactors(g)
#    2243 else:
#    2244     new_ring = ring.clone(domain=domain.get_ring())
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:2158, in PolyElement.cofactors(f, g)
#    2155     return h, cff, cfg
#    2157 J, (f, g) = f.deflate(g)
# -> 2158 h, cff, cfg = f._gcd(g)
#    2160 return (h.inflate(J), cff.inflate(J), cfg.inflate(J))
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:2191, in PolyElement._gcd(f, g)
#    2189     return f._gcd_QQ(g)
#    2190 elif ring.domain.is_ZZ:
# -> 2191     return f._gcd_ZZ(g)
#    2192 else: # TODO: don't use dense representation (port PRS algorithms)
#    2193     return ring.dmp_inner_gcd(f, g)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:2196, in PolyElement._gcd_ZZ(f, g)
#    2195 def _gcd_ZZ(f, g):
# -> 2196     return heugcd(f, g)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/heuristicgcd.py:85, in heugcd(f, g)
#      82 h = _gcd_interpolate(h, x, ring)
#      83 h = h.primitive()[1]
# ---> 85 cff_, r = f.div(h)
#      87 if not r:
#      88     cfg_, r = g.div(h)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:1467, in PolyElement.div(self, fv)
#    1465 divoccurred = 0
#    1466 while i < s and divoccurred == 0:
# -> 1467     expv = p.leading_expv()
#    1468     term = term_div((expv, p[expv]), (expvs[i], fv[i][expvs[i]]))
#    1469     if term is not None:
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:1699, in PolyElement.leading_expv(self)
#    1684 """Leading monomial tuple according to the monomial ordering.
#    1685
#    1686 Examples
#    (...)
#    1696
#    1697 """
#    1698 if self:
# -> 1699     return self.ring.leading_expv(self)
#    1700 else:
#    1701     return None
#
# KeyboardInterrupt:

# %%
# Out:
# No real permutation matrix found, trying complex matrices...

# %%
import sympy as sp

# Define symbols for the elements of the matrix T (complex numbers)
t11, t12, t13, t14 = sp.symbols('t11 t12 t13 t14', complex=True)
t21, t22, t23, t24 = sp.symbols('t21 t22 t23 t24', complex=True)
t31, t32, t33, t34 = sp.symbols('t31 t32 t33 t34', complex=True)
t41, t42, t43, t44 = sp.symbols('t41 t42 t43 t44', complex=True)

# Define the matrix T
T = sp.Matrix([
    [t11, t12, t13, t14],
    [t21, t22, t23, t24],
    [t31, t32, t33, t34],
    [t41, t42, t43, t44]
])

# Define matrix A
a, b, c, d = sp.symbols('a b c d', real=True)  # Assume a, b, c, d are real
A = sp.Matrix([
    [0, a, 0, 1],
    [1, 0, b, 0],
    [0, -1, 0, c],
    [d, 0, 1, 0]
])

# Define matrix B
B = sp.Matrix([
    [0, d, 0, 1],
    [1, 0, -a, 0],
    [0, -1, 0, -b],
    [c, 0, 1, 0]
])

# Compute T * A * T^(-1)
T_inv = T.inv()  # Inverse of T
B_computed = T * A * T_inv  # B = T A T^(-1)

# Set up the equation B_computed == B and solve for the elements of T
equations = sp.Eq(B_computed, B)

# Solve the system of equations
solution = sp.solve(equations, [t11, t12, t13, t14, t21, t22, t23, t24, t31, t32, t33, t34, t41, t42, t43, t44])

# Print the solution
print("Solution for T:")
sp.pprint(solution)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 42
#      39 equations = sp.Eq(B_computed, B)
#      41 # Solve the system of equations
# ---> 42 solution = sp.solve(equations, [t11, t12, t13, t14, t21, t22, t23, t24, t31, t32, t33, t34, t41, t42, t43, t44])
#      44 # Print the solution
#      45 print("Solution for T:")
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/solvers.py:1172, in solve(f, *symbols, **flags)
#    1170         solution = _solve(f[0], *symbols, **flags)
#    1171 else:
# -> 1172     linear, solution = _solve_system(f, symbols, **flags)
#    1173 assert type(solution) is list
#    1174 assert not solution or type(solution[0]) is dict, solution
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/solvers.py:1899, in _solve_system(exprs, symbols, **flags)
#    1897 else:
#    1898     try:
# -> 1899         result = solve_poly_system(polys, *symbols)
#    1900         if result:
#    1901             solved_syms = symbols
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/polysys.py:78, in solve_poly_system(seq, strict, *gens, **args)
#      75         except SolveFailed:
#      76             pass
# ---> 78 return solve_generic(polys, opt, strict=strict)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/polysys.py:333, in solve_generic(polys, opt, strict)
#     330     return solutions
#     332 try:
# --> 333     result = _solve_reduced_system(polys, opt.gens, entry=True)
#     334 except CoercionFailed:
#     335     raise NotImplementedError
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/solvers/polysys.py:273, in solve_generic.<locals>._solve_reduced_system(system, gens, entry)
#     270     zeros = list(roots(system[0], gens[-1], strict=strict).keys())
#     271     return [(zero,) for zero in zeros]
# --> 273 basis = groebner(system, gens, polys=True)
#     275 if len(basis) == 1 and basis[0].is_ground:
#     276     if not entry:
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/polytools.py:7338, in groebner(F, *gens, **args)
#    7287 @public
#    7288 def groebner(F, *gens, **args):
#    7289     """
#    7290     Computes the reduced Groebner basis for a set of polynomials.
#    7291
#    (...)
#    7336
#    7337     """
# -> 7338     return GroebnerBasis(F, *gens, **args)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/polytools.py:7377, in GroebnerBasis.__new__(cls, F, *gens, **args)
#    7373 ring = PolyRing(opt.gens, opt.domain, opt.order)
#    7375 polys = [ring.from_dict(poly.rep.to_dict()) for poly in polys if poly]
# -> 7377 G = _groebner(polys, ring, method=opt.method)
#    7378 G = [Poly._from_dict(g, opt) for g in G]
#    7380 return cls._new(G, opt)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/groebnertools.py:43, in groebner(seq, ring, method)
#      40     else:
#      41         seq = [ s.set_ring(ring) for s in seq ]
# ---> 43 G = _groebner(seq, ring)
#      45 if orig is not None:
#      46     G = [ g.clear_denoms()[1].set_ring(orig) for g in G ]
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/groebnertools.py:238, in _buchberger(f, ring)
#     236 # ordering divisors is on average more efficient [Cox] page 111
#     237 G1 = sorted(G, key=lambda g: order(f[g].LM))
# --> 238 ht = normal(h, G1)
#     240 if ht:
#     241     G, CP = update(G, CP, ht[1])
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/groebnertools.py:104, in _buchberger.<locals>.normal(g, J)
#     103 def normal(g, J):
# --> 104     h = g.rem([ f[j] for j in J ])
#     106     if not h:
#     107         return None
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:1507, in PolyElement.rem(self, G)
#    1505 while f:
#    1506     for g in G:
# -> 1507         tq = term_div(ltf, g.LT)
#    1508         if tq is not None:
#    1509             m, c = tq
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:1782, in PolyElement.LT(self)
#    1780 @property
#    1781 def LT(self):
# -> 1782     expv = self.leading_expv()
#    1783     if expv is None:
#    1784         return (self.ring.zero_monom, self.ring.domain.zero)
#
# File ~/miniconda3/envs/topins/lib/python3.12/site-packages/sympy/polys/rings.py:1699, in PolyElement.leading_expv(self)
#    1684 """Leading monomial tuple according to the monomial ordering.
#    1685
#    1686 Examples
#    (...)
#    1696
#    1697 """
#    1698 if self:
# -> 1699     return self.ring.leading_expv(self)
#    1700 else:
#    1701     return None
#
# KeyboardInterrupt:

# %%
import sympy as sp

# Define symbolic variables for the matrix elements
a, b, c, d = sp.symbols('a b c d')
i = sp.I  # Imaginary unit

# Define matrix A
A = sp.Matrix([
    [0, a, 0, 1],
    [1, 0, b, 0],
    [0, -1, 0, c],
    [d, 0, 1, 0]
])

# Define matrix B
B = sp.Matrix([
    [0, d, 0, 1],
    [1, 0, -a, 0],  # i^2 * a = -a
    [0, -1, 0, -b], # i^2 * b = -b
    [c, 0, 1, 0]
])

# Manually construct a potential transformation matrix T
# Based on the observation, we can try the following matrix:
T = sp.Matrix([
    [1, 0, 0, 0],
    [0, 0, -i, 0],
    [0, -i, 0, 0],
    [0, 0, 0, 1]
])

# Compute T_inv (inverse of T)
T_inv = T.inv()

# Verify the equation B = T * A * T_inv
B_computed = T * A * T_inv

# Simplify the result
B_computed_simplified = sp.simplify(B_computed)

# Check if B_computed equals B
if B_computed_simplified == B:
    print("The transformation matrix T is correct!")
else:
    print("The transformation matrix T is incorrect.")
    print("Computed B:")
    sp.pprint(B_computed_simplified)
    print("Expected B:")
    sp.pprint(B)
# Out:
# The transformation matrix T is incorrect.
# Computed B:
# ⎡0   0  ⅈ⋅a   1  ⎤
# ⎢                ⎥
# ⎢0   0  -1   -ⅈ⋅c⎥
# ⎢                ⎥
# ⎢-ⅈ  b   0    0  ⎥
# ⎢                ⎥
# ⎣d   ⅈ   0    0  ⎦
# Expected B:
# ⎡0  d   0   1 ⎤
# ⎢             ⎥
# ⎢1  0   -a  0 ⎥
# ⎢             ⎥
# ⎢0  -1  0   -b⎥
# ⎢             ⎥
# ⎣c  0   1   0 ⎦
